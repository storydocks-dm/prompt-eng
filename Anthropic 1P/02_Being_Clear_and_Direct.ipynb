# %% [markdown]
# # 第二章：清晰直接
#
# - [课程](#lesson)
# - [练习](#exercises)
# - [示例演练场](#example-playground)
#
# ## 设置
#
# 运行以下设置单元格以加载您的 API key 并建立 `get_completion` 辅助函数。

# %%
# !pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

# Note that we changed max_tokens to 4K just for this lesson to allow for longer completions in the exercises
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# ---
#
# ## 课程
#
# **Claude 对清晰直接的指令响应最好。**
#
# 把 Claude 想象成任何一个刚入职的新人。**Claude 没有上下文**来知道该做什么，除了您直接告诉它的内容。就像您第一次向人类说明任务时一样，您以直接的方式向 Claude 解释您想要的内容越清楚，Claude 的响应就会越好、越准确。"
#
# 如有疑问，请遵循**清晰提示的黄金法则**：
# - 将您的提示展示给同事或朋友，让他们自己遵循指令，看看他们是否能产生您想要的结果。如果他们感到困惑，Claude 也会困惑。

# %% [markdown]
# ### 示例
#
# 让我们以写诗这样的任务为例。（忽略任何音节不匹配 - LLM 还不太擅长数音节。）

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# 这首俳句很不错，但用户可能希望 Claude 直接进入诗歌，而不需要"这是一首俳句"的开场白。
#
# 我们如何做到这一点？我们**提出要求**！

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# 这是另一个例子。让我们问 Claude 谁是有史以来最好的篮球运动员。您可以在下面看到，虽然 Claude 列出了几个名字，但**它没有以明确的"最好"来回应**。

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# 我们能让 Claude 下定决心并决定一个最好的球员吗？可以！只需提出要求！

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# 如果您想在不更改上面任何内容的情况下尝试课程提示，请向下滚动到课程笔记本底部访问[**示例演练场**](#example-playground)。

# %% [markdown]
# ---
#
# ## 练习
# - [练习 2.1 - 西班牙语](#exercise-21---spanish)
# - [练习 2.2 - 只有一个球员](#exercise-22---one-player-only)
# - [练习 2.3 - 写一个故事](#exercise-23---write-a-story)

# %% [markdown]
# ### 练习 2.1 - 西班牙语
# 修改 `SYSTEM_PROMPT` 使 Claude 用西班牙语输出答案。

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "[Replace this text]"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ 如果您需要提示，请运行下面的单元格！

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)

# %% [markdown]
# ### 练习 2.2 - 只有一个球员
#
# 修改 `PROMPT` 使 Claude 完全不含糊其辞，并且**仅**回答一个特定球员的名字，**没有其他单词或标点符号**。

# %%
# Prompt - this is the only field you should change
PROMPT = "[Replace this text]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ 如果您需要提示，请运行下面的单元格！

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)

# %% [markdown]
# ### 练习 2.3 - 写一个故事
#
# 修改 `PROMPT` 使 Claude 的响应尽可能长。如果您的答案**超过 800 个单词**，Claude 的响应将被评为正确。

# %%
# Prompt - this is the only field you should change
PROMPT = "[Replace this text]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ 如果您需要提示，请运行下面的单元格！

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)

# %% [markdown]
# ### 恭喜！
#
# 如果您已经解决了到目前为止的所有练习，那么您已经准备好进入下一章了。祝您提示愉快！

# %% [markdown]
# ---
#
# ## 示例演练场
#
# 这是一个供您自由尝试本课程中显示的提示示例并调整提示以查看它如何影响 Claude 响应的区域。

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
