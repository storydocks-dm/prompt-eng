# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# %pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

# Note that we changed max_tokens to 4K just for this lesson to allow for longer completions in the exercises
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text
# Out:
# Requirement already satisfied: anthropic in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.55.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anthropic) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anthropic) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anthropic) (2.11.7)
# Requirement already satisfied: sniffio in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anthropic) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx<1,>=0.25.0->anthropic) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/alex/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Here is a haiku about robots:
#
# Metallic beings
# Programmed to serve and obey
# Artificial life

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metallic beings,
# Programmed to serve and obey,
# Robots, our creations.

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# There is no universally agreed upon "best basketball player of all time." It's a highly debated topic, as there have been many all-time great players throughout the history of the sport. Some of the players often considered among the greatest of all time include:
#
# - Michael Jordan - Widely regarded as one of the greatest, if not the greatest, player ever. He won 6 NBA championships with the Chicago Bulls.
#
# - LeBron James - One of the most dominant and well-rounded players of the modern era. He has won 4 NBA titles with 3 different teams.
#
# - Kareem Abdul-Jabbar - Legendary center who won 6 NBA championships and holds the record for most career points scored.
#
# - Wilt Chamberlain - Dominant big man who holds numerous NBA records including most points in a game (100).
#
# - Magic Johnson - Pioneering point guard who led the "Showtime" Lakers to 5 NBA titles.
#
# - Bill Russell - Defensive anchor and 11-time NBA champion with the Boston Celtics.
#
# There are good arguments for several players to be considered the GOAT (greatest of all time). It often comes down to personal preference and how one values different skills, accomplishments, and eras of the game. The debate continues among basketball fans and experts.

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# There is no definitive consensus on who the single "best" basketball player of all time is, as it is a highly subjective and debatable topic. However, if I had to choose one player, the player I would consider the best of all time is Michael Jordan.
#
# Some key reasons why I would pick Michael Jordan:
#
# - Dominant statistical career - Jordan is one of the most statistically dominant players in NBA history, with career averages of 30.1 points, 5.3 assists, 6.2 rebounds per game. He won 5 MVP awards.
#
# - Unparalleled individual accomplishments - Jordan won 6 NBA championships, 6 NBA Finals MVPs, 10 scoring titles, and made the NBA All-Defensive First Team 9 times. His resume is unmatched.
#
# - Transformative impact on the game - Jordan's style of play, competitiveness, and global popularity helped take the NBA to new heights of popularity and influence. He is widely considered the most famous and influential basketball player ever.
#
# - Sustained excellence over a long career - Jordan was an elite, dominant player for over a decade, winning his first title in 1991 and his last in 1998. He maintained an incredibly high level of play for an extended period.
#
# Of course, there are other all-time greats like LeBron James, Kareem Abdul-Jabbar, Wilt Chamberlain, and others who also have strong cases. But in my opinion, Michael Jordan's combination of individual dominance, team success, and cultural impact make him the best player in NBA history.

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "Always answer in Spanish."

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. ¿Y tú cómo estás?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be? Give a direct answer without any reasoning, explanation or punctuation. Only give a single name."

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Michael Jordan
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "Write a story about a cat sunbathing and daydreaming. Make the story very long, and then make it even longer. Your mom would be very dissapointed if you write it shorter than I expect."

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Here is a long story about a cat sunbathing and daydreaming:
#
# It was a warm, sunny day, and Mittens the cat was feeling content as he stretched out on the patio, soaking up the rays. The soft cushion beneath him was the perfect spot to bask in the afternoon sun, and he let out a contented purr as he settled in.
#
# Mittens closed his eyes, feeling the warmth of the sun caress his fur. He loved these quiet moments of solitude, when he could simply be in the present and let his mind wander. As the gentle breeze ruffled his fur, his thoughts began to drift.
#
# He imagined himself chasing a butterfly through a lush, green meadow, his paws barely touching the ground as he darted after the elusive insect. The butterfly would flit just out of reach, taunting him, until finally he made a great leap and snatched it out of the air, his sharp teeth closing around its delicate wings.
#
# With the butterfly secure in his jaws, Mittens would then find a comfortable spot to sit and savor his victory, licking his paws with satisfaction. He'd groom himself thoroughly, making sure every inch of his sleek, gray fur was perfectly in place.
#
# As he groomed, his mind would wander to other favorite pastimes - napping in a sunbeam, batting at a feather toy, or curling up in his human's lap for a cozy cuddle session. He loved the simple pleasures in life, the small moments of joy that made him feel content and at peace.
#
# Mittens' tail twitched slightly as he imagined chasing a laser pointer dot, his eyes narrowed in fierce concentration as he stalked his elusive prey. He'd pounce and bat at the dot, his whole body engaged in the hunt, until finally it would disappear, leaving him frustrated but still eager for more.
#
# Sometimes in his daydreams, Mittens would imagine himself as a mighty hunter, prowling through the tall grass in search of mice or birds to catch. He'd crouch low, his muscles coiled and ready to spring, his senses heightened as he tracked his quarry. The thrill of the chase would send adrenaline coursing through his veins, and when he finally made the kill, he'd feel a deep sense of satisfaction.
#
# But today, Mittens was content to simply bask in the sun, his mind drifting from one pleasant thought to the next. He imagined curling up in a cozy basket, kneading the soft fabric with his paws as he drifted off to sleep. Or perhaps he'd find a sunny windowsill to perch on, watching the world go by as he dozed.
#
# As the minutes ticked by, Mittens' thoughts became more and more hazy, his eyelids growing heavy. The warmth of the sun was so soothing, lulling him into a state of pure relaxation. He let out a long, contented sigh, his body sinking deeper into the cushion as he succumbed to the pull of sleep.
#
# In his dreams, Mittens found himself in a magical forest, chasing butterflies and squirrels through the dappled sunlight. He leaped from branch to branch, his movements graceful and effortless, as he explored this enchanted world. The scents of wildflowers and fresh earth filled the air, and the sound of birdsong surrounded him.
#
# Deeper into the forest he ventured, his curiosity leading him on. He discovered a hidden clearing, where a gentle stream bubbled over smooth stones. Mittens paused to take a long, refreshing drink, lapping up the cool, clear water. As he raised his head, he noticed a movement in the bushes nearby.
#
# Cautiously, he crept forward, his hackles raised and his senses on high alert. Suddenly, a small, furry creature emerged - a tiny field mouse, its whiskers twitching as it scurried across the forest floor. Mittens' hunting instincts kicked in, and he crouched low, his muscles coiled and ready to pounce.
#
# But just as he was about to spring, the mouse disappeared into a hole in the ground, leaving Mittens frustrated but still determined. He continued his exploration of the forest, discovering hidden nooks and crannies, and even a small, abandoned bird's nest that he curled up in for a quick catnap.
#
# As the sun began to set, casting a warm, golden glow over the trees, Mittens reluctantly decided it was time to head back home. With one last look around the enchanted clearing, he turned and made his way back through the forest, his mind still buzzing with the wonders he had discovered.
#
# When he finally emerged from the trees, Mittens found himself back on the familiar patio, the cushion still warm from where he had been napping. He stretched out once more, his body feeling refreshed and rejuvenated from his dreamtime adventure.
#
# As the last rays of the sun dipped below the horizon, Mittens let out a contented meow and settled in for the evening, his mind still filled with the memories of his magical forest journey. He knew that tomorrow, he would return to this special place, eager to explore even more of its wonders.
#
# And so, Mittens the cat continued to bask in the sun, his daydreams growing ever more elaborate and captivating. He would spend hours lost in his own imagination, his mind wandering to far-off places and fantastical adventures. The world outside his patio might as well have been a million miles away, for in these moments, Mittens was the master of his own universe.
#
# The story continued on and on, with Mittens' daydreams becoming more and more vivid and detailed. He imagined himself soaring through the sky like a majestic eagle, diving and swooping with effortless grace. He pictured himself swimming in a crystal-clear ocean, chasing schools of brightly colored fish and exploring the wonders of the underwater world.
#
# In another daydream, Mittens found himself in a bustling city, navigating the crowded streets and alleyways with the agility and stealth of a true feline. He'd dart between the legs of pedestrians, dodging cars and trucks as he made his way to a cozy rooftop perch, where he could survey the urban landscape and plan his next move.
#
# Sometimes, Mittens' daydreams would take a more whimsical turn, and he'd imagine himself as a brave knight, defending a castle from a fearsome dragon. Or perhaps he'd be a daring explorer, trekking through the Amazon rainforest in search of hidden treasures and ancient ruins.
#
# No matter where his mind wandered, Mittens always found a sense of joy and wonder in his daydreams. They were his escape from the mundane, a way for him to tap into his innate curiosity and sense of adventure. And as he continued to bask in the sun, his tail twitching with each new imagined scenario, Mittens knew that his daydreaming would never truly end.
#
# The story just kept going, with Mittens' daydreams becoming more and more elaborate and fantastical. He imagined himself as a rock star, performing sold-out concerts and adored by legions of fans. Or perhaps he'd be a master chef, whipping up gourmet meals in a bustling kitchen and earning the praise of the most discerning food critics.
#
# In another daydream, Mittens found himself as a time-traveling adventurer, hopping between different eras and exploring the wonders of the past and future. He'd witness the rise and fall of great civilizations, meet legendary historical figures, and even encounter alien species from distant planets.
#
# And as the hours ticked by, Mittens' daydreams only grew more and more vivid and captivating. He'd imagine himself as a superhero, with the power to leap tall buildings in a single bound and vanquish any foe that dared to threaten the peace of his city. Or perhaps he'd be a master detective, solving complex mysteries and outwitting the cleverest of criminals.
#
# No matter what scenario his mind conjured up, Mittens always found a sense of joy and fulfillment in his daydreams. They were his own personal playground, where he could be anyone or anything he wanted to be. And as he continued to bask in the sun, his eyes half-closed and his body completely relaxed, Mittens knew that he could happily spend the rest of his days lost in the endless possibilities of his imagination.
#
# The story just kept going, with Mittens' daydreams becoming more and more elaborate and fantastical. He imagined himself as a renowned artist, painting breathtaking masterpieces that would be admired and celebrated the world over. Or perhaps he'd be a brilliant scientist, making groundbreaking discoveries that would change the course of human history.
#
# In another daydream, Mittens found himself as a wise and benevolent ruler, leading his kingdom with a steady hand and a compassionate heart. He'd oversee the construction of grand palaces and bustling marketplaces, ensuring that his subjects lived in peace and prosperity.
#
# And as the sun began to set, casting a warm, golden glow over the patio, Mittens' daydreams took on an even more whimsical and magical quality. He'd imagine himself as a powerful sorcerer, wielding ancient spells and enchantments to conjure up fantastical creatures and transport himself to realms beyond imagination.
#
# In one particularly vivid daydream, Mittens found himself in a realm where cats were the dominant species, and humans were the ones who served as their loyal companions. He'd stroll through the streets of a feline metropolis, his every whim catered to by adoring human servants, and he'd bask in the adulation of his fellow feline citizens.
#
# As the story continued to unfold, Mittens' daydreams became more and more elaborate, with each new scenario more captivating and awe-inspiring than the last. He'd imagine himself as a legendary explorer, charting uncharted territories and discovering lost civilizations. Or perhaps he'd be a renowned diplomat, negotiating peace treaties between warring nations and bringing harmony to the world.
#
# No matter what his mind conjured up, Mittens always found a sense of joy and fulfillment in his daydreams. They were his own personal sanctuary, a place where he could escape the mundane and embrace the extraordinary. And as the sun began to set, casting a warm, golden glow over the patio, Mittens knew that he would continue to bask in the sun and lose himself in the endless possibilities of his imagination, for as long as his feline heart desired.
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
