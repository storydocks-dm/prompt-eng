# %% [markdown]
# # 附录 10.3：搜索和检索
#
# 您知道您可以使用 Claude 来**为您搜索 Wikipedia** 吗？Claude 可以查找和检索文章，此时您还可以使用 Claude 来总结文章或回答有关文章的问题。
#
# 本附录是一个演示 notebook，展示了如何使用 Wikipedia 搜索 API 和 Claude 来创建一个简单的搜索和检索系统。这个系统可以回答需要实时信息的问题，而 Claude 的训练数据中可能没有这些信息。
#
# **注意：** 本 notebook 仅用于演示目的。在生产环境中，您需要处理错误情况，实施速率限制，并可能使用更强大的搜索和检索系统。
