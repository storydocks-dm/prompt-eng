# %% [markdown]
# # 教程使用说明
#
# 本教程需要首先运行这个初始 notebook，以便为工作坊中的所有 notebook 存储依赖包和环境变量

# %% [markdown]
# ## 开始使用
#
# 1. 将此仓库克隆到本地机器。
#
# 2. 通过运行以下命令来安装所需的依赖包：

# %%
# %pip install -qU pip
# %pip install -qr ../requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 3. 安装依赖包后重启 kernel

# %%
# restart kernel
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")

# %% [markdown]
# ---
#
# ## 使用说明与技巧 💡
#
# - 本课程使用 temperature 为 0 的 Claude 3 Haiku。我们将在课程后面详细讨论 temperature。现在，只需了解这些设置可以产生更确定性的结果即可。本课程中的所有提示工程技术也适用于上一代的传统 Claude 模型，如 Claude 2 和 Claude Instant 1.2。
#
# - 您可以使用 `Shift + Enter` 来执行单元格并移动到下一个单元格。
#
# - 当您到达教程页面底部时，请导航到文件夹中的下一个编号文件，或者如果您已完成该章节文件中的内容，则导航到下一个编号文件夹。
#
# ### Anthropic SDK 和 Messages API
# 在本教程中，我们将使用 [Anthropic python SDK](https://docs.anthropic.com/claude/reference/claude-on-amazon-bedrock) 和 [Messages API](https://docs.anthropic.com/claude/reference/messages_post)。
#
# 下面是本教程中运行提示的示例。

# %% [markdown]
# 首先，我们设置并存储模型名称和区域。

# %%
import boto3
session = boto3.Session() # create a boto3 session to dynamically get and set the region name
AWS_REGION = session.region_name
print("AWS Region:", AWS_REGION)
MODEL_NAME = "anthropic.claude-3-haiku-20240307-v1:0"

# %store MODEL_NAME
# %store AWS_REGION

# %% [markdown]
# 然后，我们创建 `get_completion`，这是一个辅助函数，用于向 Claude 发送提示并返回 Claude 生成的响应。现在运行该单元格。

# %%
from anthropic import AnthropicBedrock

client = AnthropicBedrock(aws_region=AWS_REGION)

def get_completion(prompt, system=''):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ],
        system=system
    )
    return message.content[0].text

# %% [markdown]
# 现在我们将为 Claude 编写一个示例提示，并通过运行 `get_completion` 辅助函数来打印 Claude 的输出。运行下面的单元格将在其下方打印 Claude 的响应。
#
# 随意修改提示字符串，以获得 Claude 的不同响应。

# %%
# Prompt
prompt = "Hello, Claude!"

# Get Claude's response
print(get_completion(prompt))

# %% [markdown]
# 前面定义的 `MODEL_NAME` 和 `AWS_REGION` 变量将在整个教程中使用。只需确保从上到下运行每个教程页面的单元格。
